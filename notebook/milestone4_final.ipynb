# %%
import sys
import os
# Add project root to Python path
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), "../src"))
sys.path.append(PROJECT_ROOT)
PROJECT_ROOT
from app import app

# %%
pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: langgraph in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from -r ../requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: google-auth in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from -r ../requirements.txt (line 2)) (2.47.0)
# Requirement already satisfied: google-auth-oauthlib in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from -r ../requirements.txt (line 3)) (1.2.3)
# Requirement already satisfied: google-api-python-client in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from -r ../requirements.txt (line 4)) (2.187.0)
# Requirement already satisfied: langchain-core>=0.1 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from langgraph->-r ../requirements.txt (line 1)) (1.2.6)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from langgraph->-r ../requirements.txt (line 1)) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from langgraph->-r ../requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from langgraph->-r ../requirements.txt (line 1)) (0.3.1)
# Requirement already satisfied: pydantic>=2.7.4 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from langgraph->-r ../requirements.txt (line 1)) (2.12.5)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from langgraph->-r ../requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph->-r ../requirements.txt (line 1)) (1.12.1)
# Requirement already satisfied: httpx>=0.25.2 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph->-r ../requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph->-r ../requirements.txt (line 1)) (3.11.5)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from google-auth->-r ../requirements.txt (line 2)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from google-auth->-r ../requirements.txt (line 2)) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from rsa<5,>=3.1.4->google-auth->-r ../requirements.txt (line 2)) (0.6.1)
# Collecting google-auth (from -r ../requirements.txt (line 2))
#   Downloading google_auth-2.41.1-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from google-auth-oauthlib->-r ../requirements.txt (line 3)) (2.0.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from google-auth->-r ../requirements.txt (line 2)) (6.2.2)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from google-api-python-client->-r ../requirements.txt (line 4)) (0.31.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from google-api-python-client->-r ../requirements.txt (line 4)) (0.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from google-api-python-client->-r ../requirements.txt (line 4)) (2.28.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from google-api-python-client->-r ../requirements.txt (line 4)) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ../requirements.txt (line 4)) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ../requirements.txt (line 4)) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ../requirements.txt (line 4)) (1.27.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ../requirements.txt (line 4)) (2.32.5)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->-r ../requirements.txt (line 4)) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ../requirements.txt (line 4)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ../requirements.txt (line 4)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ../requirements.txt (line 4)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ../requirements.txt (line 4)) (2025.11.12)
# Requirement already satisfied: anyio in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph->-r ../requirements.txt (line 1)) (4.12.0)
# Requirement already satisfied: httpcore==1.* in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph->-r ../requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph->-r ../requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from langchain-core>=0.1->langgraph->-r ../requirements.txt (line 1)) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from langchain-core>=0.1->langgraph->-r ../requirements.txt (line 1)) (0.6.2)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from langchain-core>=0.1->langgraph->-r ../requirements.txt (line 1)) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from langchain-core>=0.1->langgraph->-r ../requirements.txt (line 1)) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from langchain-core>=0.1->langgraph->-r ../requirements.txt (line 1)) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from langchain-core>=0.1->langgraph->-r ../requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from langchain-core>=0.1->langgraph->-r ../requirements.txt (line 1)) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph->-r ../requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph->-r ../requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph->-r ../requirements.txt (line 1)) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from pydantic>=2.7.4->langgraph->-r ../requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from pydantic>=2.7.4->langgraph->-r ../requirements.txt (line 1)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from pydantic>=2.7.4->langgraph->-r ../requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/nitishrmaladakar/anaconda3/envs/new_plant_env/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->-r ../requirements.txt (line 3)) (3.3.1)
# Downloading google_auth-2.41.1-py2.py3-none-any.whl (221 kB)
# Installing collected packages: google-auth
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.47.0
#     Uninstalling google-auth-2.47.0:
#       Successfully uninstalled google-auth-2.47.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-genai 1.57.0 requires google-auth[requests]<3.0.0,>=2.46.0, but you have google-auth 2.41.1 which is incompatible.
# Successfully installed google-auth-2.41.1
# Note: you may need to restart the kernel to use updated packages.

# %%
state = {
"response": "Hi Bob, please join the meeting.",
"memory": {
"to": "your_email@gmail.com",
"start_time": "2026-01-22T10:00:00",
"end_time": "2026-01-22T11:00:00",
},
}
app.invoke(
state,
config={"configurable": {"thread_id": "bob-test"}}
)
# Out:
# {'response': 'Dear Bob,\n\nThis is a professional email.\n\nBest regards,\n',
#  'memory': {'to': 'your_email@gmail.com',
#   'start_time': '2026-01-22T10:00:00',
#   'end_time': '2026-01-22T11:00:00'},
#  'paused': False}

# %%
state["memory"]["human_edit"] = "Robert"
app.invoke(
state,
config={"configurable": {"thread_id": "bob-test"}}
)
# Out:
# {'response': 'Dear Bob,\n\nThis is a professional email.\n\nBest regards,\n',
#  'memory': {'to': 'your_email@gmail.com',
#   'start_time': '2026-01-22T10:00:00',
#   'end_time': '2026-01-22T11:00:00',
#   'human_edit': 'Robert'},
#  'paused': False}

# %%
state = {
"response": "Hi Bob, please join the meeting.",
"memory": {
"to": "your_email@gmail.com",
"start_time": "2026-01-23T10:00:00",
"end_time": "2026-01-23T11:00:00",
},
}
result = app.invoke(
state,
config={"configurable": {"thread_id": "bob-test"}}
)
print(result["response"])
# Out:
# Dear Bob,
#
# This is a professional email.
#
# Best regards,
