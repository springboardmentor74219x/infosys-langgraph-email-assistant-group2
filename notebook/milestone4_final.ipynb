# %%
import sys
import os
from app import app

# Add project root to Python path
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(PROJECT_ROOT)

PROJECT_ROOT
# Out:
# 'c:\\Users\\Gajendra\\Desktop\\SpringBoard\\infosys-langgraph-email-assistant-group2'

# %%
state = app.invoke({
    "input": "Please draft an email to Bob about the meeting tomorrow",
},
config={
        "configurable": {
            "thread_id": "email-thread-1"
        }
    }
)
state
# Out:
# {'response': 'Dear Bob,\n\nI hope you are doing well.\nThis is a reminder about our meeting scheduled for tomorrow.\n\nBest regards,\n',
#  'memory': {},
#  'paused': False}

# %%
state = app.invoke(
    {
        "input": "Actually, call him Robert, not Bob.",
        "memory": state.get("memory", {})
    },
    config={
        "configurable": {
            "thread_id": "email-thread-1"  # SAME ID
        }
    }
)
state
# Out:
# {'response': 'Dear Robert,\n\nThis is a professional email.\n\nBest regards,\n',
#  'memory': {'name_preference': 'Robert'},
#  'paused': False}

# %%
app.invoke({
    "input": "Please draft an email to Bob about the meeting tomorrow",
    "memory": state.get("memory", {})
},
config={
        "configurable": {
            "thread_id": "email-thread-1"  # SAME ID
        }
    }
)
# Out:
# {'response': 'Dear Robert,\n\nI hope you are doing well.\nThis is a reminder about our meeting scheduled for tomorrow.\n\nBest regards,\n',
#  'memory': {'name_preference': 'Robert'},
#  'paused': False}
