# %%
import sys
import os

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(PROJECT_ROOT)

PROJECT_ROOT
from app import app
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 8
#       5 sys.path.append(PROJECT_ROOT)
#       7 PROJECT_ROOT
# ----> 8 from app import app
#
# ModuleNotFoundError: No module named 'app'

# %%
state = {
    "response": "Hi Bob, please join the meeting.",
    "memory": {
        "to": "your_email@gmail.com",
        "start_time": "2026-01-22T10:00:00",
        "end_time": "2026-01-22T11:00:00",
    },
}

app.invoke(
    state,
    config={"configurable": {"thread_id": "bob-test"}}
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 10
#       1 state = {
#       2     "response": "Hi Bob, please join the meeting.",
#       3     "memory": {
#    (...)      7     },
#       8 }
# ---> 10 app.invoke(
#      11     state,
#      12     config={"configurable": {"thread_id": "bob-test"}}
#      13 )
#
# NameError: name 'app' is not defined

# %%
state["memory"]["human_edit"] = "Robert"

app.invoke(
    state,
    config={"configurable": {"thread_id": "bob-test"}}
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 state["memory"]["human_edit"] = "Robert"
# ----> 3 app.invoke(
#       4     state,
#       5     config={"configurable": {"thread_id": "bob-test"}}
#       6 )
#
# NameError: name 'app' is not defined

# %%
state = {
    "response": "Hi Bob, please join the meeting.",
    "memory": {
        "to": "your_email@gmail.com",
        "start_time": "2026-01-23T10:00:00",
        "end_time": "2026-01-23T11:00:00",
    },
}

result = app.invoke(
    state,
    config={"configurable": {"thread_id": "bob-test"}}
)

print(result["response"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 10
#       1 state = {
#       2     "response": "Hi Bob, please join the meeting.",
#       3     "memory": {
#    (...)      7     },
#       8 }
# ---> 10 result = app.invoke(
#      11     state,
#      12     config={"configurable": {"thread_id": "bob-test"}}
#      13 )
#      15 print(result["response"])
#
# NameError: name 'app' is not defined
