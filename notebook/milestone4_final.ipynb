# %%
import sys
import os

# Add project root to Python path
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(PROJECT_ROOT)

PROJECT_ROOT
from app import app

# %%
pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: langgraph in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from -r ../requirements.txt (line 1)) (1.0.6)
# Requirement already satisfied: google-auth in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from -r ../requirements.txt (line 2)) (2.47.0)
# Requirement already satisfied: google-auth-oauthlib in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from -r ../requirements.txt (line 3)) (1.2.4)
# Requirement already satisfied: google-api-python-client in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from -r ../requirements.txt (line 4)) (2.188.0)
# Requirement already satisfied: langchain-core>=0.1 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from langgraph->-r ../requirements.txt (line 1)) (1.2.7)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from langgraph->-r ../requirements.txt (line 1)) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from langgraph->-r ../requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from langgraph->-r ../requirements.txt (line 1)) (0.3.1)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from langgraph->-r ../requirements.txt (line 1)) (2.11.7)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from langgraph->-r ../requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph->-r ../requirements.txt (line 1)) (1.12.1)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph->-r ../requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph->-r ../requirements.txt (line 1)) (3.11.5)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from google-auth->-r ../requirements.txt (line 2)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from google-auth->-r ../requirements.txt (line 2)) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from rsa<5,>=3.1.4->google-auth->-r ../requirements.txt (line 2)) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from google-auth-oauthlib->-r ../requirements.txt (line 3)) (2.0.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client->-r ../requirements.txt (line 4)) (0.31.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client->-r ../requirements.txt (line 4)) (0.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client->-r ../requirements.txt (line 4)) (2.28.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client->-r ../requirements.txt (line 4)) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ../requirements.txt (line 4)) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ../requirements.txt (line 4)) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ../requirements.txt (line 4)) (1.27.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ../requirements.txt (line 4)) (2.32.4)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->-r ../requirements.txt (line 4)) (3.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ../requirements.txt (line 4)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ../requirements.txt (line 4)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ../requirements.txt (line 4)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ../requirements.txt (line 4)) (2025.6.15)
# Requirement already satisfied: anyio in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph->-r ../requirements.txt (line 1)) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph->-r ../requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph->-r ../requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from langchain-core>=0.1->langgraph->-r ../requirements.txt (line 1)) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from langchain-core>=0.1->langgraph->-r ../requirements.txt (line 1)) (0.5.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from langchain-core>=0.1->langgraph->-r ../requirements.txt (line 1)) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from langchain-core>=0.1->langgraph->-r ../requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from langchain-core>=0.1->langgraph->-r ../requirements.txt (line 1)) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from langchain-core>=0.1->langgraph->-r ../requirements.txt (line 1)) (4.14.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from langchain-core>=0.1->langgraph->-r ../requirements.txt (line 1)) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph->-r ../requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph->-r ../requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph->-r ../requirements.txt (line 1)) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.7.4->langgraph->-r ../requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.7.4->langgraph->-r ../requirements.txt (line 1)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.7.4->langgraph->-r ../requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->-r ../requirements.txt (line 3)) (3.3.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\theer\appdata\local\programs\python\python311\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph->-r ../requirements.txt (line 1)) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
state = app.invoke({
    "input": "Please draft an email to Bob about the meeting tomorrow"
})
state
# Out:
# {'response': 'Dear Bob,\n\nI hope you are doing well.\nThis is a reminder about our meeting scheduled for tomorrow.\n\nBest regards,\n',
#  'memory': {},
#  'paused': False}

# %%
state = app.invoke({
    "input": "Actually, call him Robert, not Bob.",
    "memory": state.get("memory", {})
})
state
# Out:
# {'response': 'Dear Robert,\n\nThis is a professional email.\n\nBest regards,\n',
#  'memory': {'name_preference': 'Robert'},
#  'paused': False}

# %%
app.invoke({
    "input": "Please draft an email to Bob about the meeting tomorrow",
    "memory": state.get("memory", {})
})
# Out:
# {'response': 'Dear Robert,\n\nI hope you are doing well.\nThis is a reminder about our meeting scheduled for tomorrow.\n\nBest regards,\n',
#  'memory': {'name_preference': 'Robert'},
#  'paused': False}
