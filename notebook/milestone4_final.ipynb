# %%
import sys, os

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

from app import app

# %%
state = {
    "response": "Hi Bob, please join the meeting.",
    "memory": {
        "to": "misa.kanaujiya2023@vitstudent.ac.in",
        "start_time": "2026-01-22T10:00:00",
        "end_time": "2026-01-22T11:00:00",
        "send_email": False   # 🔴 IMPORTANT
    }
}

result = app.invoke(
    state,
    config={"configurable": {"thread_id": "bob-test"}}
)

print(result["response"])
# Out:
# Hi Bob, please join the meeting.

# %%
state["memory"]["human_edit"] = "Robert"

result = app.invoke(
    state,
    config={"configurable": {"thread_id": "bob-test"}}
)

print(result["response"])
# Out:
# Hi Robert, please join the meeting.

# %%
state["memory"]["send_email"] = True

result = app.invoke(
    state,
    config={"configurable": {"thread_id": "bob-test"}}
)

print(result["response"])
# Out:
# Hi Robert, please join the meeting.
