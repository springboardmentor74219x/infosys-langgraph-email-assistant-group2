# %%
import sys
import os
# Add project root to Python path
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(PROJECT_ROOT)
PROJECT_ROOT
import importlib
import app
importlib.reload(app)
from app import app

# %%
import sys, importlib

sys.modules.pop("app", None)
import app
importlib.reload(app)

from app import app
print(app)
# Out:
# <langgraph.graph.state.CompiledStateGraph object at 0x000001B0C3AB2EA0>

# %%
from app import app as graph

# %%
import sys, importlib
sys.modules.pop("app", None)
import app
importlib.reload(app)
from app import app as graph

# %%
state = graph.invoke({
    "input": "Please draft an email to Bob about the meeting tomorrow",
    "memory": {
        "to": "your_email@gmail.com",
        "start_time": "2026-01-22T10:00:00",
        "end_time": "2026-01-22T11:00:00",
        "send_email": True
    }
})
print(state)
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=452634889035-k4p7n4buuha286598658if2dgnuddoso.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A56400%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fgmail.send+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcalendar.events&state=kLnnJvZifiGlcq4QmGR7MK19eTYwCb&access_type=offline

# %%
import app
print("Loaded from:", app.__file__)

state = graph.invoke({
    "input": "Please draft an email to Bob about the meeting tomorrow",
    "memory": {
        "to": "bhumika.prajapati13825_email@gmail.com",
        "start_time": "2026-01-22T10:00:00",
        "end_time": "2026-01-22T11:00:00",
        "send_email": True
    }
})

print(state)
# Out:
# Loaded from: c:\Users\PC-LENOVO\Desktop\infosys\infosys-langgraph-email-assistant-group2\app.py
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=452634889035-k4p7n4buuha286598658if2dgnuddoso.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A58300%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fgmail.send+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcalendar.events&state=LRDKhuHBll89j8vY2rGY2QPlKR4kFr&access_type=offline

# %%
state = app.invoke({
    "input": "Please draft an email to Bob about the meeting tomorrow"
})
print(state)
# Out:
# {'input': 'Please draft an email to Bob about the meeting tomorrow', 'response': 'Hi Bob, please join the meeting.', 'memory': {}}

# %%
state = app.invoke({
    "input": "Actually, call him Robert, not Bob.",
    "memory": state.get("memory", {})
})
state
# Out:
# {'input': 'Actually, call him Robert, not Bob.',
#  'memory': {},
#  'response': 'Hi Bob, please join the meeting.'}

# %%
app.invoke({
    "input": "Please draft an email to Bob about the meeting tomorrow",
    "memory": state.get("memory", {})
})
# Out:
# {'input': 'Please draft an email to Bob about the meeting tomorrow',
#  'memory': {},
#  'response': 'Hi Bob, please join the meeting.'}
