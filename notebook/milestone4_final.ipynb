# %%
import sys
import os

# Add project root to Python path
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(PROJECT_ROOT)

PROJECT_ROOT
from app import app
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 9
#       6 sys.path.append(PROJECT_ROOT)
#       8 PROJECT_ROOT
# ----> 9 from app import app
#
# File c:\Users\skgha\OneDrive\Desktop\Email Assisstant\infosys-langgraph-email-assistant-group2\app.py:3
#       1 from langgraph.graph import StateGraph
#       2 from memory import memory
# ----> 3 from tools import send_email, create_calendar_invite
#       5 def agent_node(state):
#       6     email = state["email"]
#
# File c:\Users\skgha\OneDrive\Desktop\Email Assisstant\infosys-langgraph-email-assistant-group2\tools.py:4
#       1 import base64
#       2 from email.message import EmailMessage
# ----> 4 from google_auth_oauthlib.flow import InstalledAppFlow
#       5 from googleapiclient.discovery import build
#       6 from google.auth.transport.requests import Request
#
# ModuleNotFoundError: No module named 'google_auth_oauthlib'
