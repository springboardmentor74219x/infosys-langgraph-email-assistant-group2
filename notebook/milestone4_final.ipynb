# %%
import sys
import os

# Add project root (adjust path if needed)
PROJECT_ROOT = os.path.abspath(r"C:\Users\skgha\OneDrive\Desktop\Email Assisstant\infosys-langgraph-email-assistant-group2")
sys.path.append(PROJECT_ROOT)

from app import app

print("Milestone-4 app imported successfully!")
# Out:
# ✅ App compiled successfully!
# Milestone-4 app imported successfully!

# %%
state = app.invoke({
    "input": "Please draft an email to Bob about the meeting tomorrow"
})
state
# Out:
# {'response': '✅ Email sent successfully!'}

# %%
state = app.invoke({
    "input": "Actually, call him Robert, not Bob.",
    "memory": state.get("memory", {})
})
state
# Out:
# {'response': '✅ Email sent successfully!'}

# %%
app.invoke({
    "input": "Please draft an email to Bob about the meeting tomorrow",
    "memory": state.get("memory", {})
})
# Out:
# {'response': '✅ Email sent successfully!'}
