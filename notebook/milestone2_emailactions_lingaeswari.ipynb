# %% [markdown]
# ### Load the dataset

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Deepalakshmi\Downloads\data\milestone1_output_lingaeswari.csv")
print("successfully loaded!")
# Out:
# successfully loaded!
