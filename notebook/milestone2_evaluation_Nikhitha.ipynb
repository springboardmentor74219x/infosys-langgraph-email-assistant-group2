# %%
import pandas as pd

# %%
df = pd.read_csv("../data/email_evaluation_dataset_Nikhitha.csv")
df.head()
# Out:
#                                           email_text expected_action  \
# 0  Please attend the project status meeting tomor...         respond
# 1  Your internship completion certificate is read...         respond
# 2  Kindly submit your assignment by end of day today         respond
# 3  This is a reminder to clear the pending invoic...         respond
# 4  Thank you for applying. We will get back to yo...         respond
#
#   expected_tone
# 0        polite
# 1        polite
# 2       neutral
# 3        urgent
# 4        polite

# %%
def email_assistant(text):
    t = str(text).lower()
    
    if any(k in t for k in ['invoice','payment','due','meeting','submit','confirm']):
        action = 'respond'
        tone = 'polite'
    elif any(k in t for k in ['password','security','alert','unauthorized','suspicious']):
        action = 'notify'
        tone = 'urgent'
    else:
        action = 'ignore'
        tone = 'neutral'
        
    return action, tone

# %%
df[['predicted_action','predicted_tone']] = df['email_text'].apply(
    lambda x: pd.Series(email_assistant(x))
)

df.head()
# Out:
#                                           email_text expected_action  \
# 0  Please attend the project status meeting tomor...         respond
# 1  Your internship completion certificate is read...         respond
# 2  Kindly submit your assignment by end of day today         respond
# 3  This is a reminder to clear the pending invoic...         respond
# 4  Thank you for applying. We will get back to yo...         respond
#
#   expected_tone predicted_action predicted_tone
# 0        polite          respond         polite
# 1        polite           ignore        neutral
# 2       neutral          respond         polite
# 3        urgent          respond         polite
# 4        polite           ignore        neutral

# %%
df['action_correct'] = df['predicted_action'] == df['expected_action']
df['tone_correct'] = df['predicted_tone'] == df['expected_tone']

df.head()
# Out:
#                                           email_text expected_action  \
# 0  Please attend the project status meeting tomor...         respond
# 1  Your internship completion certificate is read...         respond
# 2  Kindly submit your assignment by end of day today         respond
# 3  This is a reminder to clear the pending invoic...         respond
# 4  Thank you for applying. We will get back to yo...         respond
#
#   expected_tone predicted_action predicted_tone  action_correct  tone_correct
# 0        polite          respond         polite            True          True
# 1        polite           ignore        neutral           False         False
# 2       neutral          respond         polite            True         False
# 3        urgent          respond         polite            True         False
# 4        polite           ignore        neutral           False         False

# %%
action_accuracy = df['action_correct'].mean() * 100
tone_accuracy = df['tone_correct'].mean() * 100

action_accuracy, tone_accuracy
# Out:
# (np.float64(60.0), np.float64(65.0))

# %%
errors = df[df['action_correct'] == False][
    ['email_text','expected_action','predicted_action']
]

errors.head(10)
# Out:
#                                            email_text expected_action  \
# 1   Your internship completion certificate is read...         respond
# 4   Thank you for applying. We will get back to yo...         respond
# 13  The internship orientation session will be hel...         respond
# 14  Kindly review the attached document and share ...         respond
# 15    Your library book return date has been extended         respond
# 16  Please update your contact details in the stud...         respond
# 17  This is a final reminder to complete your cour...         respond
# 18           Your request for leave has been approved         respond
# 19  The exam schedule for next semester has been r...         respond
# 29  Urgent notice: multiple failed login attempts ...          notify
#
#    predicted_action
# 1            ignore
# 4            ignore
# 13           ignore
# 14           ignore
# 15           ignore
# 16           ignore
# 17           ignore
# 18           ignore
# 19           ignore
# 29           ignore

# %%
df.to_csv("../data/milestone2_output_Nikhitha.csv", index=False)

# %%
import pandas as pd

df = pd.read_csv("../data/sample_emails_with_triage_200.csv")
df.head()
# Out:
#    id                sender                      subject  \
# 0   1       alerts@bank.com       Password Reset Request
# 1   2       alerts@bank.com  Congratulations! You've Won
# 2   3  no-reply@service.com          Promotion: Big Sale
# 3   4        sales@shop.com               Monthly Report
# 4   5  no-reply@service.com                       Survey
#
#                                                 body priority  triage_label
# 0  Reminder: The client meeting is scheduled at 1...      low  notify_human
# 1  Your invoice of INR 25515.09 is due on 2025-12...      low       respond
# 2  Reminder: The client meeting is scheduled at 1...      low        ignore
# 3  Hello team, please find the attached weekly re...   medium       respond
# 4  Hello team, please find the attached weekly re...      low       respond

# %%
def email_assistant(email_text):
    text = str(email_text).lower()

    if "urgent" in text or "deadline" in text or "password" in text:
        return "notify", "urgent"
    elif "thank you" in text or "thanks" in text:
        return "ignore", "polite"
    else:
        return "respond", "neutral"

# %%
predictions = []

for _, row in df.iterrows():
    action, tone = email_assistant(row["body"])
    predictions.append({
        "id": row["id"],
        "predicted_intent": action,
        "predicted_tone": tone
    })

pred_df = pd.DataFrame(predictions)
pred_df.head()
# Out:
#    id predicted_intent predicted_tone
# 0   1          respond        neutral
# 1   2          respond        neutral
# 2   3          respond        neutral
# 3   4          respond        neutral
# 4   5          respond        neutral

# %%
def evaluate(row):
    score = 0
    if row["predicted_intent"] == row["ideal_intent"]:
        score += 1
    if row["predicted_tone"] == row["ideal_tone"]:
        score += 1
    return score

eval_df = df.merge(pred_df, on="id")
eval_df["score"] = eval_df.apply(evaluate, axis=1)

accuracy = (eval_df["score"].sum() / (len(eval_df) * 2)) * 100
accuracy
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\nikhi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ideal_intent'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 10
#       7     return score
#       9 eval_df = df.merge(pred_df, on="id")
# ---> 10 eval_df["score"] = eval_df.apply(evaluate, axis=1)
#      12 accuracy = (eval_df["score"].sum() / (len(eval_df) * 2)) * 100
#      13 accuracy
#
# File c:\Users\nikhi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)  10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\nikhi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File c:\Users\nikhi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File c:\Users\nikhi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[4], line 3, in evaluate(row)
#       1 def evaluate(row):
#       2     score = 0
# ----> 3     if row["predicted_intent"] == row["ideal_intent"]:
#       4         score += 1
#       5     if row["predicted_tone"] == row["ideal_tone"]:
#
# File c:\Users\nikhi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File c:\Users\nikhi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File c:\Users\nikhi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'ideal_intent'

# %%
import pandas as pd

df = pd.read_csv("../data/sample_emails_with_triage_200.csv")
df.columns
# Out:
# Index(['id', 'sender', 'subject', 'body', 'priority', 'triage_label',
#        'clean_text', 'triage', 'ideal_intent', 'ideal_tone'],
#       dtype='object')

# %%
eval_df = df.merge(pred_df, on="id")

eval_df["score"] = (
    (eval_df["predicted_intent"] == eval_df["ideal_intent"]).astype(int) +
    (eval_df["predicted_tone"] == eval_df["ideal_tone"]).astype(int)
)

accuracy = (eval_df["score"].sum() / (len(eval_df) * 2)) * 100
accuracy
# Out:
# np.float64(0.0)

# %%
def evaluate(row):
    score = 0
    if row["predicted_intent"] == row["ideal_intent"]:
        score += 1
    if row["predicted_tone"] == row["ideal_tone"]:
        score += 1
    return score

eval_df = df.merge(pred_df, on="id")
eval_df["score"] = eval_df.apply(evaluate, axis=1)

accuracy = (eval_df["score"].sum() / (len(eval_df) * 2)) * 100
accuracy
# Out:
# np.float64(0.0)

# %%
eval_df.to_csv(
    "../data/milestone2_output_Nikhitha.csv",
    index=False
)
