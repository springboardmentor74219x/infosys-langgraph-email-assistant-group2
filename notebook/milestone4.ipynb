# %%
import sys
import os

# Add project root to Python path
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(PROJECT_ROOT)

PROJECT_ROOT
from app import app

# %%
#Test State
state = {
    "input": "Email Bob about project update",
    "memory": {
        "to": "test.receiver@gmail.com",
        "subject": "Project Update",
        "human_edit": None
    }
}

# %%
app.invoke(
    state,
    config={"configurable": {"thread_id": "bob-test"}}
)
# Out:
# {'response': 'Dear Bob,\n\nThis is a professional email.\n\nBest regards,\n',
#  'memory': {'to': 'test.receiver@gmail.com',
#   'subject': 'Project Update',
#   'human_edit': None},
#  'paused': False}

# %%
state = app.invoke({
    "input": "Please draft an email to Bob about the meeting tomorrow"
})
state
# Out:
# {'response': 'Dear Bob,\n\nI hope you are doing well.\nThis is a reminder about our meeting scheduled for tomorrow.\n\nBest regards,\n',
#  'memory': {},
#  'paused': False}

# %%
state = app.invoke({
    "input": "Actually, call him Robert, not Bob.",
    "memory": state.get("memory", {})
})
state
# Out:
# {'response': 'Dear Robert,\n\nThis is a professional email.\n\nBest regards,\n',
#  'memory': {'name_preference': 'Robert'},
#  'paused': False}

# %%
state = {
    "input": "Email Bob about the project update tomorrow",
    "memory": {
        "to": "bob@example.com",
        "subject": "Project Update"
    }
}

result = app.invoke(state)
result
# Out:
# {'response': 'Dear Bob,\n\nThis is a professional email.\n\nBest regards,\n',
#  'memory': {'to': 'bob@example.com', 'subject': 'Project Update'},
#  'paused': False}
