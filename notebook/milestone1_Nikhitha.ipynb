# %%
import pandas as pd
import re

# %%
df=pd.read_csv("../data/sample_emails_with_triage_200.csv")
df.head()
# Out:
#    id                sender                      subject  \
# 0   1       alerts@bank.com       Password Reset Request
# 1   2       alerts@bank.com  Congratulations! You've Won
# 2   3  no-reply@service.com          Promotion: Big Sale
# 3   4        sales@shop.com               Monthly Report
# 4   5  no-reply@service.com                       Survey
#
#                                                 body priority  triage_label
# 0  Reminder: The client meeting is scheduled at 1...      low  notify_human
# 1  Your invoice of INR 25515.09 is due on 2025-12...      low       respond
# 2  Reminder: The client meeting is scheduled at 1...      low        ignore
# 3  Hello team, please find the attached weekly re...   medium       respond
# 4  Hello team, please find the attached weekly re...      low       respond

# %%
def clean_email(text):
    if isinstance(text, str):
        text = text.lower()
        text = re.sub(r"http\S+", "", text)
        text = re.sub(r"<.*?>", "", text)
        text = re.sub(r"[^a-zA-Z0-9 ]", " ", text)
        text = re.sub(r"\s+", " ", text).strip()
        return text
    else:
        return ""
    
src_col = "email_text" if "email_text" in df.columns else "body"
df["clean_text"] = df[src_col].apply(clean_email)
df.head()
df.head()
# Out:
#    id                sender                      subject  \
# 0   1       alerts@bank.com       Password Reset Request
# 1   2       alerts@bank.com  Congratulations! You've Won
# 2   3  no-reply@service.com          Promotion: Big Sale
# 3   4        sales@shop.com               Monthly Report
# 4   5  no-reply@service.com                       Survey
#
#                                                 body priority  triage_label  \
# 0  Reminder: The client meeting is scheduled at 1...      low  notify_human
# 1  Your invoice of INR 25515.09 is due on 2025-12...      low       respond
# 2  Reminder: The client meeting is scheduled at 1...      low        ignore
# 3  Hello team, please find the attached weekly re...   medium       respond
# 4  Hello team, please find the attached weekly re...      low       respond
#
#                                           clean_text
# 0  reminder the client meeting is scheduled at 10...
# 1  your invoice of inr 25515 09 is due on 2025 12...
# ...

# %%
def triage(text):
    if any(keyword in text for keyword in ["urgent", "immediately", "asap", "action required"]):
        return "respond_or_act"
    elif any(keyword in text for keyword in ["please check", "review", "verify"]):
        return "notify_human"
    else:
        return "ignore"

if "clean_text" not in df.columns:
    src_col = "email_text" if "email_text" in df.columns else "body"
    df["clean_text"] = df[src_col].apply(clean_email)

df["triage"] = df["clean_text"].apply(triage)
df.head()
# Out:
#    id                sender                      subject  \
# 0   1       alerts@bank.com       Password Reset Request
# 1   2       alerts@bank.com  Congratulations! You've Won
# 2   3  no-reply@service.com          Promotion: Big Sale
# 3   4        sales@shop.com               Monthly Report
# 4   5  no-reply@service.com                       Survey
#
#                                                 body priority  triage_label  \
# 0  Reminder: The client meeting is scheduled at 1...      low  notify_human
# 1  Your invoice of INR 25515.09 is due on 2025-12...      low       respond
# 2  Reminder: The client meeting is scheduled at 1...      low        ignore
# 3  Hello team, please find the attached weekly re...   medium       respond
# 4  Hello team, please find the attached weekly re...      low       respond
#
#                                           clean_text  triage
# 0  reminder the client meeting is scheduled at 10...  ignore
# ...

# %%
df.to_csv("../data/milestone1_Nikhitha.csv", index=False)

# %%
# !ls ../data
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import os
os.listdir("../data")
# Out:
# ['.gitkeep',
#  'milestone1_mohammadshahidulla.csv',
#  'milestone1_mvarsha.csv',
#  'milestone1_Nikhitha.csv',
#  'milestone1_output.csv',
#  'sample_emails.csv',
#  'sample_emails_with_triage_200.csv']

# %%
os.listdir("../data")
# Out:
# ['.gitkeep',
#  'milestone1_mohammadshahidulla.csv',
#  'milestone1_mvarsha.csv',
#  'milestone1_Nikhitha.csv',
#  'milestone1_output.csv',
#  'sample_emails.csv',
#  'sample_emails_with_triage_200.csv']
