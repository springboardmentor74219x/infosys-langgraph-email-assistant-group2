# %% [markdown]
# Milestone2

# %%
import pandas as pd
import numpy as np
import re

# %%
data = pd.read_csv("../data/milestone1_output.csv")
data.head()
# Out:
#    id                sender                      subject  \
# 0   1       alerts@bank.com       Password Reset Request
# 1   2       alerts@bank.com  Congratulations! You've Won
# 2   3  no-reply@service.com          Promotion: Big Sale
# 3   4        sales@shop.com               Monthly Report
# 4   5  no-reply@service.com                       Survey
#
#                                                 body priority  triage_label  \
# 0  Reminder: The client meeting is scheduled at 1...      low  notify_human
# 1  Your invoice of INR 25515.09 is due on 2025-12...      low       respond
# 2  Reminder: The client meeting is scheduled at 1...      low        ignore
# 3  Hello team, please find the attached weekly re...   medium       respond
# 4  Hello team, please find the attached weekly re...      low       respond
#
#                                           clean_text  \
# 0  reminder the client meeting is scheduled at  t...
# 1  your invoice of inr  is due on  please pay to ...
# 2  reminder the client meeting is scheduled at  t...
# 3  hello team please find the attached weekly rep...
# 4  hello team please find the attached weekly rep...
#
#                                             keywords          triage
# 0  ['reminder', 'client', 'meeting', 'scheduled',...  respond_or_act
# 1  ['invoice', 'inr', 'due', 'please', 'pay', 'av...    notify_human
# 2  ['reminder', 'client', 'meeting', 'scheduled',...  respond_or_act
# 3  ['hello', 'team', 'please', 'find', 'attached'...  respond_or_act
# 4  ['hello', 'team', 'please', 'find', 'attached'...  respond_or_act

# %%
len(data)
# Out:
# 200

# %%
#create a column of ideal_response---use if elif logic
#triage _lablerule--return no respone,

def classify_email(text):
    text = text.lower()

    notify_terms = ["refund", "urgent", "password"]
    ignore_terms = ["newsletter", "promotion"]

    if any(word in text for word in notify_terms):
        return "notify_human"

    if any(word in text for word in ignore_terms):
        return "ignore"
    
    return "respond_or_act"

# %%
data["predicted_triage"] = data["clean_text"].apply(classify_email)
data[["body", "predicted_triage"]].head()
# Out:
#                                                 body predicted_triage
# 0  Reminder: The client meeting is scheduled at 1...   respond_or_act
# 1  Your invoice of INR 25515.09 is due on 2025-12...   respond_or_act
# 2  Reminder: The client meeting is scheduled at 1...   respond_or_act
# 3  Hello team, please find the attached weekly re...   respond_or_act
# 4  Hello team, please find the attached weekly re...   respond_or_act

# %%
output_cols = ["body", "predicted_triage"]
data.to_csv("../data/milestone1_output.csv", columns=output_cols, index=False)

# %%
#select 100 test email

test_data = (
    df.sample(n=100, random_state=42)
        .reset_index(drop=True)
)

test_data.head()
# Out:
#     id                sender             subject  \
# 0   96  no-reply@service.com   Weekly Newsletter
# 1   16     news@techblog.com     Payment Overdue
# 2   31     news@techblog.com   Weekly Newsletter
# 3  159  no-reply@service.com  Welcome to Service
# 4  129        sales@shop.com         Invoice Due
#
#                                                 body priority  triage_label  \
# 0  Your order #3634 has been shipped and is expec...      low        ignore
# 1  Hi, don't miss our sale with discounts up to 7...      low  notify_human
# 2  Notice: Your account will be locked unless ver...     high  notify_human
# 3  Reminder: The client meeting is scheduled at 9...      low       respond
# 4  Your order #6464 has been shipped and is expec...      low       respond
#
#                                           clean_text  \
# 0  your order  has been shipped and is expected t...
# 1  hi dont miss our sale with discounts up to  on...
# 2  notice your account will be locked unless veri...
# 3  reminder the client meeting is scheduled at  t...
# 4  your order  has been shipped and is expected t...
#
#                                             keywords          triage
# 0        ['order', 'shipped', 'expected', 'deliver']  respond_or_act
# 1  ['hi', 'dont', 'miss', 'sale', 'discounts', 's...          ignore
# 2  ['notice', 'account', 'locked', 'unless', 'ver...  respond_or_act
# 3  ['reminder', 'client', 'meeting', 'scheduled',...  respond_or_act
# 4        ['order', 'shipped', 'expected', 'deliver']  respond_or_act

# %%
df['clean_text'].head(100)
# Out:
# 0     reminder the client meeting is scheduled at  t...
# 1     your invoice of inr  is due on  please pay to ...
# 2     reminder the client meeting is scheduled at  t...
# 3     hello team please find the attached weekly rep...
# 4     hello team please find the attached weekly rep...
#                             ...
# 95    your order  has been shipped and is expected t...
# 96    security alert multiple failed login attempts ...
# 97    security alert multiple failed login attempts ...
# 98    notice your account will be locked unless veri...
# 99    your order  has been shipped and is expected t...
# Name: clean_text, Length: 100, dtype: object

# %%
def map_action(triage_type):
    response_map = {
        "ignore": "No action needed",
        "respond": "Send a reply",
        "respond_or_act": "Respond and take required action",
        "notify_human": "Escalate to human"
    }
    return response_map.get(triage_type, "Manual review required")

# %%
test_data["ideal_response"] = test_data["triage_label"].apply(map_action)
test_data[["triage_label", "ideal_response"]].head()
# Out:
#    triage_label     ideal_response
# 0        ignore   No action needed
# 1  notify_human  Escalate to human
# 2  notify_human  Escalate to human
# 3       respond       Send a reply
# 4       respond       Send a reply
