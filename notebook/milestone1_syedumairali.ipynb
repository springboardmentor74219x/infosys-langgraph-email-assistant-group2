# %%
# !pip install pandas nltk
import pandas as pd
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\pantla\appdata\roaming\python\python313\site-packages (2.3.3)
# Requirement already satisfied: nltk in c:\users\pantla\appdata\roaming\python\python313\site-packages (3.9.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\pantla\appdata\roaming\python\python313\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pantla\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pantla\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pantla\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: click in c:\users\pantla\appdata\roaming\python\python313\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in c:\users\pantla\appdata\roaming\python\python313\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\pantla\appdata\roaming\python\python313\site-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in c:\users\pantla\appdata\roaming\python\python313\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: six>=1.5 in c:\users\pantla\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama in c:\users\pantla\appdata\roaming\python\python313\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Pantla\AppData\Roaming\nltk_data...

# %%
df = pd.read_csv("../data/sample_emails_with_triage_200.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv("../data/sample_emails_with_triage_200.csv")
#       2 df.head()
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
import numpy as np

# %%
import re

# %%
df = pd.read_csv("../data/sample_emails_with_triage_200.csv")
df.head()
# Out:
#    id                sender                      subject  \
# 0   1       alerts@bank.com       Password Reset Request
# 1   2       alerts@bank.com  Congratulations! You've Won
# 2   3  no-reply@service.com          Promotion: Big Sale
# 3   4        sales@shop.com               Monthly Report
# 4   5  no-reply@service.com                       Survey
#
#                                                 body priority  triage_label
# 0  Reminder: The client meeting is scheduled at 1...      low  notify_human
# 1  Your invoice of INR 25515.09 is due on 2025-12...      low       respond
# 2  Reminder: The client meeting is scheduled at 1...      low        ignore
# 3  Hello team, please find the attached weekly re...   medium       respond
# 4  Hello team, please find the attached weekly re...      low       respond

# %%
import pandas as pd
df = pd.read_csv("../data/sample_emails_with_triage_200.csv")
df.head()
# Out:
#    id                sender                      subject  \
# 0   1       alerts@bank.com       Password Reset Request
# 1   2       alerts@bank.com  Congratulations! You've Won
# 2   3  no-reply@service.com          Promotion: Big Sale
# 3   4        sales@shop.com               Monthly Report
# 4   5  no-reply@service.com                       Survey
#
#                                                 body priority  triage_label
# 0  Reminder: The client meeting is scheduled at 1...      low  notify_human
# 1  Your invoice of INR 25515.09 is due on 2025-12...      low       respond
# 2  Reminder: The client meeting is scheduled at 1...      low        ignore
# 3  Hello team, please find the attached weekly re...   medium       respond
# 4  Hello team, please find the attached weekly re...      low       respond

# %%
df['clean_text'] = (
    df['body']
    .str.lower()
    .str.replace('[^a-zA-Z ]', '', regex=True)
)

df[['body', 'clean_text']].head()
# Out:
#                                                 body  \
# 0  Reminder: The client meeting is scheduled at 1...
# 1  Your invoice of INR 25515.09 is due on 2025-12...
# 2  Reminder: The client meeting is scheduled at 1...
# 3  Hello team, please find the attached weekly re...
# 4  Hello team, please find the attached weekly re...
#
#                                           clean_text
# 0  reminder the client meeting is scheduled at  t...
# 1  your invoice of inr  is due on  please pay to ...
# 2  reminder the client meeting is scheduled at  t...
# 3  hello team please find the attached weekly rep...
# 4  hello team please find the attached weekly rep...

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

stop_words = set(stopwords.words("english"))

df['keywords'] = df['clean_text'].apply(
    lambda x: [w for w in x.split() if w not in stop_words]
)

df[['clean_text', 'keywords']].head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Pantla\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                           clean_text  \
# 0  reminder the client meeting is scheduled at  t...
# 1  your invoice of inr  is due on  please pay to ...
# 2  reminder the client meeting is scheduled at  t...
# 3  hello team please find the attached weekly rep...
# 4  hello team please find the attached weekly rep...
#
#                                             keywords
# 0  [reminder, client, meeting, scheduled, tomorro...
# 1  [invoice, inr, due, please, pay, avoid, late, ...
# 2  [reminder, client, meeting, scheduled, tomorro...
# 3  [hello, team, please, find, attached, weekly, ...
# 4  [hello, team, please, find, attached, weekly, ...

# %%
def triage_rule(text):
    text = text.lower()

    if "refund" in text or "urgent" in text or "password" in text:
        return "notify_human"

    if "newsletter" in text or "promotion" in text:
        return "ignore"

    return "respond_or_act"

df['triage'] = df['clean_text'].apply(triage_rule)
df[['body', 'triage']].head()
# Out:
#                                                 body          triage
# 0  Reminder: The client meeting is scheduled at 1...  respond_or_act
# 1  Your invoice of INR 25515.09 is due on 2025-12...  respond_or_act
# 2  Reminder: The client meeting is scheduled at 1...  respond_or_act
# 3  Hello team, please find the attached weekly re...  respond_or_act
# 4  Hello team, please find the attached weekly re...  respond_or_act

# %%
df.to_csv("../data/milestone1_output.csv", index=False)

# %%
# 1. Imports + load
import pandas as pd
import re
from IPython.display import display

# adjust path if needed
CSV_PATH = "../data/sample_emails_with_triage_200.csv"
df = pd.read_csv(CSV_PATH)
print("Loaded rows:", len(df))
display(df.head())
# Out:
# Loaded rows: 200
#    id                sender                      subject  \
# 0   1       alerts@bank.com       Password Reset Request
# 1   2       alerts@bank.com  Congratulations! You've Won
# 2   3  no-reply@service.com          Promotion: Big Sale
# 3   4        sales@shop.com               Monthly Report
# 4   5  no-reply@service.com                       Survey
#
#                                                 body priority  triage_label
# 0  Reminder: The client meeting is scheduled at 1...      low  notify_human
# 1  Your invoice of INR 25515.09 is due on 2025-12...      low       respond
# 2  Reminder: The client meeting is scheduled at 1...      low        ignore
# 3  Hello team, please find the attached weekly re...   medium       respond
# 4  Hello team, please find the attached weekly re...      low       respond

# %%
# 2. Create a helpful cleaned text column
# Keep words and meaningful tokens (remove only repeated whitespace and control chars)
def make_clean_text(s):
    if not isinstance(s, str):
        return ""
    s = s.strip()
    # normalize spaces and lowercase
    s = re.sub(r'\s+', ' ', s)
    s = s.lower()
    return s

# prefer 'body' column; if not, try 'email_body' or 'subject'
source_col = 'body' if 'body' in df.columns else ('email_body' if 'email_body' in df.columns else 'subject')
df['clean_text'] = df[source_col].astype(str).apply(make_clean_text)
display(df[[source_col,'clean_text']].head())
# Out:
#                                                 body  \
# 0  Reminder: The client meeting is scheduled at 1...
# 1  Your invoice of INR 25515.09 is due on 2025-12...
# 2  Reminder: The client meeting is scheduled at 1...
# 3  Hello team, please find the attached weekly re...
# 4  Hello team, please find the attached weekly re...
#
#                                           clean_text
# 0  reminder: the client meeting is scheduled at 1...
# 1  your invoice of inr 25515.09 is due on 2025-12...
# 2  reminder: the client meeting is scheduled at 1...
# 3  hello team, please find the attached weekly re...
# 4  hello team, please find the attached weekly re...

# %%
# 3. Debug-friendly triage (regex-based with priority). This returns (label, matched_pattern)
RULES = {
    'notify_human': [
        r'\binvoice\b', r'\bbill\b', r'\bpayment\b', r'\bpassword\b', r'\breset\b',
        r'\bfraud\b', r'\bchargeback\b', r'\bdispute\b', r'\bdenied\b', r'\boverdue\b'
    ],
    'respond_or_act': [
        r'\bmeeting\b', r'\bschedule\b', r'\bscheduled\b', r'\battached\b', r'\battachment\b',
        r'\bplease find\b', r'\bplease review\b', r'\baction required\b', r'\burgent\b', r'\basap\b'
    ],
    'ignore': [
        r'\bunsubscribe\b', r'\bpromotion\b', r'\bsale\b', r'\boffer\b', r'\bnewsletter\b',
        r'\bsurvey\b', r'\bcongratulations\b'
    ]
}
COMPILED = {k:[re.compile(p, flags=re.I) for p in v] for k,v in RULES.items()}

def triage_rule_debug(text):
    if not isinstance(text, str) or text.strip()=="":
        return ('ignore','empty_text')
    for label in ['notify_human','respond_or_act','ignore']:
        for pat in COMPILED[label]:
            if pat.search(text):
                return (label, pat.pattern)
    return ('respond_or_act','default_fallback')

# apply and store both label and matched pattern
df[['triage','triage_match']] = df['clean_text'].apply(lambda t: pd.Series(triage_rule_debug(t)))
print("Triage value counts (advanced):")
print(df['triage'].value_counts())
display(df[['clean_text','triage','triage_match']].head(20))
# Out:
# Triage value counts (advanced):
# triage
# respond_or_act    127
# ignore             42
# notify_human       31
# Name: count, dtype: int64
#                                            clean_text          triage  \
# 0   reminder: the client meeting is scheduled at 1...  respond_or_act
# 1   your invoice of inr 25515.09 is due on 2025-12...    notify_human
# 2   reminder: the client meeting is scheduled at 1...  respond_or_act
# 3   hello team, please find the attached weekly re...  respond_or_act
# 4   hello team, please find the attached weekly re...  respond_or_act
# 5   your invoice of inr 38766.88 is due on 2025-12...    notify_human
# 6   congratulations! you have been selected as a l...          ignore
# 7   your order #6313 has been shipped and is expec...  respond_or_act
# 8   dear user, we detected a login from a new devi...    notify_human
# 9   your invoice of inr 32944.21 is due on 2025-12...    notify_human
# 10  reminder: the client meeting is scheduled at 1...  respond_or_act
# 11  your order #3621 has been shipped and is expec...  respond_or_act
# 12  hello team, please find the attached weekly re...  respond_or_act
# 13  reminder: the client meeting is scheduled at 1...  respond_or_act
# 14  please complete the mandatory training module ...  respond_or_act
# 15  hi, don't miss our sale with discounts up to 7...          ignore
# 16  reminder: the client meeting is scheduled at 1...  respond_or_act
# 17  hi, don't miss our sale with discounts up to 7...          ignore
# 18  please complete the mandatory training module ...  respond_or_act
# 19  please complete the mandatory training module ...  respond_or_act
#
#            triage_match
# 0           \bmeeting\b
# 1           \binvoice\b
# 2           \bmeeting\b
# 3          \battached\b
# 4          \battached\b
# 5           \binvoice\b
# 6   \bcongratulations\b
# 7      default_fallback
# 8          \bpassword\b
# 9           \binvoice\b
# 10          \bmeeting\b
# 11     default_fallback
# 12         \battached\b
# 13          \bmeeting\b
# 14     default_fallback
# 15             \bsale\b
# 16          \bmeeting\b
# 17             \bsale\b
# 18     default_fallback
# 19     default_fallback

# %%
# 5. Diagnostics — use this in live demo to show interns why each label was chosen
print("Top 20 rows with triage reasons:")
display(df[['body','clean_text','triage','triage_match']].head(20))

# show a few sample rows where triage==notify_human for inspection
print("\nSample notify_human rows:")
display(df[df['triage']=='notify_human'][['body','clean_text','triage_match']].head(6))

print("\nSample respond_or_act rows:")
display(df[df['triage']=='respond_or_act'][['body','clean_text','triage_match']].head(6))

print("\nSample ignore rows:")
display(df[df['triage']=='ignore'][['body','clean_text','triage_match']].head(6))
# Out:
# Top 20 rows with triage reasons:
#                                                  body  \
# 0   Reminder: The client meeting is scheduled at 1...
# 1   Your invoice of INR 25515.09 is due on 2025-12...
# 2   Reminder: The client meeting is scheduled at 1...
# 3   Hello team, please find the attached weekly re...
# 4   Hello team, please find the attached weekly re...
# 5   Your invoice of INR 38766.88 is due on 2025-12...
# 6   Congratulations! You have been selected as a l...
# 7   Your order #6313 has been shipped and is expec...
# 8   Dear user, we detected a login from a new devi...
# 9   Your invoice of INR 32944.21 is due on 2025-12...
# 10  Reminder: The client meeting is scheduled at 1...
# 11  Your order #3621 has been shipped and is expec...
# 12  Hello team, please find the attached weekly re...
# 13  Reminder: The client meeting is scheduled at 1...
# 14  Please complete the mandatory training module ...
# 15  Hi, don't miss our sale with discounts up to 7...
# 16  Reminder: The client meeting is scheduled at 1...
# 17  Hi, don't miss our sale with discounts up to 7...
# 18  Please complete the mandatory training module ...
# 19  Please complete the mandatory training module ...
#
#                                            clean_text          triage  \
# 0   reminder: the client meeting is scheduled at 1...  respond_or_act
# 1   your invoice of inr 25515.09 is due on 2025-12...    notify_human
# 2   reminder: the client meeting is scheduled at 1...  respond_or_act
# 3   hello team, please find the attached weekly re...  respond_or_act
# 4   hello team, please find the attached weekly re...  respond_or_act
# 5   your invoice of inr 38766.88 is due on 2025-12...    notify_human
# 6   congratulations! you have been selected as a l...          ignore
# 7   your order #6313 has been shipped and is expec...  respond_or_act
# 8   dear user, we detected a login from a new devi...    notify_human
# 9   your invoice of inr 32944.21 is due on 2025-12...    notify_human
# 10  reminder: the client meeting is scheduled at 1...  respond_or_act
# 11  your order #3621 has been shipped and is expec...  respond_or_act
# 12  hello team, please find the attached weekly re...  respond_or_act
# 13  reminder: the client meeting is scheduled at 1...  respond_or_act
# 14  please complete the mandatory training module ...  respond_or_act
# 15  hi, don't miss our sale with discounts up to 7...          ignore
# 16  reminder: the client meeting is scheduled at 1...  respond_or_act
# 17  hi, don't miss our sale with discounts up to 7...          ignore
# 18  please complete the mandatory training module ...  respond_or_act
# 19  please complete the mandatory training module ...  respond_or_act
#
#            triage_match
# 0           \bmeeting\b
# 1           \binvoice\b
# 2           \bmeeting\b
# 3          \battached\b
# 4          \battached\b
# 5           \binvoice\b
# 6   \bcongratulations\b
# 7      default_fallback
# 8          \bpassword\b
# 9           \binvoice\b
# 10          \bmeeting\b
# 11     default_fallback
# 12         \battached\b
# 13          \bmeeting\b
# 14     default_fallback
# 15             \bsale\b
# 16          \bmeeting\b
# 17             \bsale\b
# 18     default_fallback
# 19     default_fallback
# Sample notify_human rows:
#                                                  body  \
# 1   Your invoice of INR 25515.09 is due on 2025-12...
# 5   Your invoice of INR 38766.88 is due on 2025-12...
# 8   Dear user, we detected a login from a new devi...
# 9   Your invoice of INR 32944.21 is due on 2025-12...
# 24  Your invoice of INR 9983.71 is due on 2025-12-...
# 27  Dear user, we detected a login from a new devi...
#
#                                            clean_text  triage_match
# 1   your invoice of inr 25515.09 is due on 2025-12...   \binvoice\b
# 5   your invoice of inr 38766.88 is due on 2025-12...   \binvoice\b
# 8   dear user, we detected a login from a new devi...  \bpassword\b
# 9   your invoice of inr 32944.21 is due on 2025-12...   \binvoice\b
# 24  your invoice of inr 9983.71 is due on 2025-12-...   \binvoice\b
# 27  dear user, we detected a login from a new devi...  \bpassword\b
# Sample respond_or_act rows:
#                                                  body  \
# 0   Reminder: The client meeting is scheduled at 1...
# 2   Reminder: The client meeting is scheduled at 1...
# 3   Hello team, please find the attached weekly re...
# 4   Hello team, please find the attached weekly re...
# 7   Your order #6313 has been shipped and is expec...
# 10  Reminder: The client meeting is scheduled at 1...
#
#                                            clean_text      triage_match
# 0   reminder: the client meeting is scheduled at 1...       \bmeeting\b
# 2   reminder: the client meeting is scheduled at 1...       \bmeeting\b
# 3   hello team, please find the attached weekly re...      \battached\b
# 4   hello team, please find the attached weekly re...      \battached\b
# 7   your order #6313 has been shipped and is expec...  default_fallback
# 10  reminder: the client meeting is scheduled at 1...       \bmeeting\b
# Sample ignore rows:
#                                                  body  \
# 6   Congratulations! You have been selected as a l...
# 15  Hi, don't miss our sale with discounts up to 7...
# 17  Hi, don't miss our sale with discounts up to 7...
# 28  Hi, don't miss our sale with discounts up to 7...
# 32  Congratulations! You have been selected as a l...
# 34  Congratulations! You have been selected as a l...
#
#                                            clean_text         triage_match
# 6   congratulations! you have been selected as a l...  \bcongratulations\b
# 15  hi, don't miss our sale with discounts up to 7...             \bsale\b
# 17  hi, don't miss our sale with discounts up to 7...             \bsale\b
# 28  hi, don't miss our sale with discounts up to 7...             \bsale\b
# 32  congratulations! you have been selected as a l...  \bcongratulations\b
# 34  congratulations! you have been selected as a l...  \bcongratulations\b

# %%
# 6. Save results for submission
OUT = "../data/milestone1_output.csv"
df.to_csv(OUT, index=False)
print("Saved:", OUT)
# Out:
# Saved: ../data/milestone1_output.csv
