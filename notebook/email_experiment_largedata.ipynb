# %%
import pandas as pd
print("Pandas is working")
# Out:
# Pandas is working

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Deepalakshmi\Downloads/sample_emails_with_triage_200.csv")
print(df.head(25))
# Out:
#     id                sender                      subject  \
# 0    1       alerts@bank.com       Password Reset Request
# 1    2       alerts@bank.com  Congratulations! You've Won
# 2    3  no-reply@service.com          Promotion: Big Sale
# 3    4        sales@shop.com               Monthly Report
# 4    5  no-reply@service.com                       Survey
# 5    6       alerts@bank.com        Unusual Login Attempt
# 6    7        hr@company.com               Project Update
# 7    8        sales@shop.com               Project Update
# 8    9     security@bank.com            Account Suspended
# 9   10      boss@company.com               Monthly Report
# 10  11     support@cloud.com                       Survey
# 11  12     news@techblog.com                Policy Update
# 12  13  teamlead@company.com         Subscription Renewal
# 13  14       alerts@bank.com                       Survey
# 14  15     security@bank.com               Security Alert
# 15  16     news@techblog.com              Payment Overdue
# 16  17       alerts@bank.com              Payment Overdue
# 17  18     support@cloud.com               Meeting Agenda
# 18  19  teamlead@company.com  Congratulations! You've Won
# 19  20        hr@company.com           Welcome to Service
# 20  21     support@cloud.com            Account Suspended
# 21  22        hr@company.com            Weekly Newsletter
# 22  23      boss@company.com          Promotion: Big Sale
# 23  24  teamlead@company.com              Payment Overdue
# 24  25        hr@company.com                  Invoice Due
#
#                                                  body priority  triage_label
# 0   Reminder: The client meeting is scheduled at 1...      low  notify_human
# 1   Your invoice of INR 25515.09 is due on 2025-12...      low       respond
# 2   Reminder: The client meeting is scheduled at 1...      low        ignore
# 3   Hello team, please find the attached weekly re...   medium       respond
# 4   Hello team, please find the attached weekly re...      low       respond
# 5   Your invoice of INR 38766.88 is due on 2025-12...      low  notify_human
# 6   Congratulations! You have been selected as a l...      low        ignore
# 7   Your order #6313 has been shipped and is expec...   medium       respond
# 8   Dear user, we detected a login from a new devi...     high  notify_human
# 9   Your invoice of INR 32944.21 is due on 2025-12...      low       respond
# 10  Reminder: The client meeting is scheduled at 1...     high       respond
# 11  Your order #3621 has been shipped and is expec...   medium       respond
# 12  Hello team, please find the attached weekly re...   medium       respond
# 13  Reminder: The client meeting is scheduled at 1...      low       respond
# 14  Please complete the mandatory training module ...   medium  notify_human
# 15  Hi, don't miss our sale with discounts up to 7...      low  notify_human
# 16  Reminder: The client meeting is scheduled at 1...   medium  notify_human
# 17  Hi, don't miss our sale with discounts up to 7...   medium        ignore
# 18  Please complete the mandatory training module ...     high       respond
# 19  Please complete the mandatory training module ...      low       respond
# 20  Notice: Your account will be locked unless ver...     high  notify_human
# 21  Please complete the mandatory training module ...      low        ignore
# 22  Your order #2545 has been shipped and is expec...      low        ignore
# 23  Security alert: multiple failed login attempts...      low  notify_human
# 24  Your invoice of INR 9983.71 is due on 2025-12-...      low       respond

# %%
df.info
# Out:
# <bound method DataFrame.info of       id                sender                      subject  \
# 0      1       alerts@bank.com       Password Reset Request
# 1      2       alerts@bank.com  Congratulations! You've Won
# 2      3  no-reply@service.com          Promotion: Big Sale
# 3      4        sales@shop.com               Monthly Report
# 4      5  no-reply@service.com                       Survey
# ..   ...                   ...                          ...
# 195  196  no-reply@service.com                Policy Update
# 196  197      boss@company.com                Order Shipped
# 197  198  no-reply@service.com            Weekly Newsletter
# 198  199     news@techblog.com              Payment Overdue
# 199  200     support@cloud.com          Promotion: Big Sale
#
#                                                   body priority  triage_label
# 0    Reminder: The client meeting is scheduled at 1...      low  notify_human
# 1    Your invoice of INR 25515.09 is due on 2025-12...      low       respond
# 2    Reminder: The client meeting is scheduled at 1...      low        ignore
# 3    Hello team, please find the attached weekly re...   medium       respond
# 4    Hello team, please find the attached weekly re...      low       respond
# ..                                                 ...      ...           ...
# 195  Security alert: multiple failed login attempts...      low  notify_human
# 196  Your order #3828 has been shipped and is expec...   medium       respond
# 197  Congratulations! You have been selected as a l...   medium        ignore
# 198  Please complete the mandatory training module ...      low  notify_human
# 199  Congratulations! You have been selected as a l...      low        ignore
#
# [200 rows x 6 columns]>

# %%
df.describe(include="all")
# Out:
#                 id                sender          subject  \
# count   200.000000                   200              200
# unique         NaN                    10               20
# top            NaN  no-reply@service.com  Action Required
# freq           NaN                    26               17
# mean    100.500000                   NaN              NaN
# std      57.879185                   NaN              NaN
# min       1.000000                   NaN              NaN
# 25%      50.750000                   NaN              NaN
# 50%     100.500000                   NaN              NaN
# 75%     150.250000                   NaN              NaN
# max     200.000000                   NaN              NaN
#
#                                                      body priority  \
# count                                                 200      200
# unique                                                 59        3
# top     Notice: Your account will be locked unless ver...      low
# freq                                                   24      119
# mean                                                  NaN      NaN
# std                                                   NaN      NaN
# min                                                   NaN      NaN
# 25%                                                   NaN      NaN
# 50%                                                   NaN      NaN
# 75%                                                   NaN      NaN
# max                                                   NaN      NaN
#
#         triage_label
# count            200
# unique             3
# top     notify_human
# freq              91
# mean             NaN
# std              NaN
# min              NaN
# 25%              NaN
# 50%              NaN
# 75%              NaN
# max              NaN
